# %%
import pandas as pd

lr = pd.read_csv('linear_regression_metrics.csv')
rf = pd.read_csv('random_forest_metrics.csv')
xgb = pd.read_csv('xgboost_metrics.csv')

comparison = pd.concat([lr, rf, xgb])
print(comparison)
